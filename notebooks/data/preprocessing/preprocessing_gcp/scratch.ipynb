# %%
import pandas as pd
import geopandas as gpd
import pickle
from pprint import pprint

# Path based modules to allow us to save files to our local machine
from pyprojroot import here
import sys
import os
root = here(project_files=[".here"])
sys.path.append(str(here()))

# Geospatial modules and WorldFloods activations mapping module
import geopandas as gpd
import pickle
import pandas as pd
from src.data.copernicusEMS import activations
from src.data import utils

from pprint import pprint

# %%
df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
                   'num_wings': [2, 0, 0, 0],
                   'num_specimen_seen': [10, 2, 1, 8]},
                  index=['falcon', 'dog', 'spider', 'fish'])

df.to_json()
df

# %%
# Checking if the geojsons were properly saved locally

# local_gjson = "/home/satyarth934/projects/ml4floods/datasets/Copernicus_unzipped_gcp/EMSR486/AOI06/EMSR486_AOI06_GRA_PRODUCT_r1_v1_floodmap.geojson"
# gcp_gjson = "gs://ml4cc_data_lake/0_DEV/0_Raw/WorldFloods/copernicus_ems/satyarth_mess/test.geojson"
gcp_geojson = "gs://ml4cc_data_lake/0_DEV/0_Raw/WorldFloods/copernicus_ems/satyarth_mess/EMSR486/AOI02/EMSR486_AOI02_DEL_PRODUCT_r1_v1_floodmap.geojson"
gpd.read_file(gcp_geojson)
# Out:
#                w_class            source  \
# 0         Flooded area             flood
# 1         Flooded area             flood
# 2         Flooded area             flood
# 3         Flooded area             flood
# 4         Flooded area             flood
# ...                ...               ...
# 1235      BH141-Stream           hydro_l
# 1236   BA010-Coastline           hydro_l
# 1237      BH141-Stream           hydro_l
# 1238      BH141-Stream           hydro_l
# 1239  area_of_interest  area_of_interest
#
#                                                geometry
# 0     POLYGON ((9.73630 40.65413, 9.73640 40.65384, ...
# 1     POLYGON ((9.43073 40.48629, 9.43105 40.48624, ...
# 2     POLYGON ((9.73300 40.64552, 9.73289 40.64541, ...
# 3     POLYGON ((9.73272 40.64477, 9.73259 40.64475, ...
# 4     POLYGON ((9.73443 40.64483, 9.73446 40.64479, ...
# ...                                                 ...
# 1235  LINESTRING (9.73411 40.64129, 9.73431 40.64132...
# ...

# %%
gcp_pickle = "gs://ml4cc_data_lake/0_DEV/0_Raw/WorldFloods/copernicus_ems/satyarth_mess/EMSR486/AOI02/EMSR486_AOI02_DEL_PRODUCT_r1_v1_metadata_floodmap.pickle"
utils.read_pickle_from_gcp(gcp_pickle)
# Out:
# {'event_id': 'EMSR486_AOI02_DEL_PRODUCT_r1_v1',
#  'layer_name': 'EMSR486_AOI02_DEL_PRODUCT_observedEventA_r1_v1',
#  'event_type': 'Flash flood',
#  'satellite_date': Timestamp('2020-12-03 09:32:00+0000', tz='UTC'),
#  'country': 'NaN',
#  'satellite': 'SPOT-6-7',
#  'bounding_box': {'west': 9.406415916000071,
#   'east': 9.76157366800004,
#   'north': 40.691914137000026,
#   'south': 40.470326767000074},
#  'reference_system': {'code_space': 'epsg', 'code': '4326'},
#  'abstract': 'NaN',
#  'purpose': 'NaN',
#  'source': 'CopernicusEMS',
#  'area_of_interest_polygon': <shapely.geometry.polygon.Polygon at 0x7f8d5485d340>,
#  'observed_event_file': 'EMSR486_AOI02_DEL_PRODUCT_observedEventA_r1_v1.shp',
#  'area_of_interest_file': 'EMSR486_AOI02_DEL_PRODUCT_areaOfInterestA_r1_v1.shp',
#  'ems_code': 'EMSR486',
#  'aoi_code': 'AOI02',
#  'satellite_pre_event': 'SPOT-6-7',
#  'timestamp_pre_event': Timestamp('2020-08-23 10:07:00+0000', tz='UTC'),
# ...

# %%
# Checking if the pickles were properly saved locally

# local_pickle = "/home/satyarth934/projects/ml4floods/datasets/Copernicus_unzipped_gcp/EMSR486/AOI06/EMSR486_AOI06_GRA_PRODUCT_r1_v1_metadata_floodmap.pickle"
gcp_pickle = "gs://ml4cc_data_lake/0_DEV/0_Raw/WorldFloods/copernicus_ems/satyarth_mess/test.json.json"
pkl = pickle.load(open(gcp_pickle, 'rb'))

pprint(pkl)
for k in pkl:
    print(type(pkl[k]))
