# %% [markdown]
# # PyTorch-Lightning Data Module
#
# In this module, we quickly demonstrate how to use the PyTorch-Lightning Module which already has the preliminary steps for preprocessing. We assume the data is already downloaded and organized in this demo.

# %%
# Helpful trick for loading the directories correction
import sys, os
from pyprojroot import here
# spyder up to find the root
root = here(project_files=[".here"])
# append to path
sys.path.append(str(here()))


from src.data.worldfloods.dataset import WorldFloodsDatasetTiled

# MATPLOTLIB Settings
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# SEABORN SETTINGS
import seaborn as sns
sns.set_context(context='talk',font_scale=0.7)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Demo Images
#
# For this demonstration, we need a S2 AND a groundtruth image. We have two that we can download.

# %%
from src.data.worldfloods.test_download import download_demo_trainsplit_image
from pathlib import Path

destination_dir = Path(root).joinpath("datasets/demo_images")

# %%
download_demo_trainsplit_image(dest_dir=destination_dir)
# Out:
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/train/S2' Is Already There.
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/train/gt' Is Already There.
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/val/S2' Is Already There.
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/val/gt' Is Already There.
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/test/S2' Is Already There.
# Folder '/home/gonzalo/ml4floods/datasets/demo_images/test/gt' Is Already There.

# %%
# !tree $destination_dir
# Out:
# /home/gonzalo/ml4floods/datasets/demo_images
# ├── test
# │   ├── S2
# │   │   └── EMSR286_09ITUANGOSOUTH_DEL_MONIT02_v1_observed_event_a.tif
# │   └── gt
# │       └── EMSR286_09ITUANGOSOUTH_DEL_MONIT02_v1_observed_event_a.tif
# ├── train
# │   ├── S2
# │   │   └── 01042016_Holmes_Creek_at_Vernon_FL.tif
# │   └── gt
# │       └── 01042016_Holmes_Creek_at_Vernon_FL.tif
# └── val
#     ├── S2
#     │   └── RS2_20161008_Water_Extent_Corail_Pestel.tif
#     └── gt
#         └── RS2_20161008_Water_Extent_Corail_Pestel.tif
#
# 9 directories, 6 files

# %% [markdown]
# ## PL - DataModule

# %% [markdown]
# #### 1.1 - Initialize Data Module

# %%
from src.data.worldfloods.lightning import WorldFloodsDataModule

wf_dm = WorldFloodsDataModule(
    data_dir=str(destination_dir),
)

# %% [markdown]
# #### 1.2 - Prepare Data

# %%
wf_dm.prepare_data()

# %% [markdown]
# #### 1.3 - Run Setup

# %%
wf_dm.setup()

# %% [markdown]
# #### 1.4 - Load Datasets (Optional)

# %%
train_ds = wf_dm.train_dataset
val_ds = wf_dm.val_dataset
test_ds = wf_dm.test_dataset

print(len(wf_dm.train_dataset), len(wf_dm.val_dataset), len(wf_dm.test_dataset))
# Out:
# 1395 256 112

# %% [markdown]
# #### 1.5 - Load DataLoaders

# %%
train_dl = wf_dm.train_dataloader()
val_dl = wf_dm.val_dataloader()
test_dl = wf_dm.test_dataloader()

print(len(train_dl), len(val_dl), len(test_dl))
# Out:
# 44 8 4

# %% [markdown]
# ## Demo - Train/Val/Test

# %%
from rasterio.plot import show as rasterio_show
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

for iloader in [train_dl, val_dl, test_dl]:
    n_tiles = 16
    n_rows = 2
    tiles_per_row = int(n_tiles / n_rows)
    iteration = 0

    # plot preamble
    fig = plt.figure(figsize=(40, 20))
    grid = ImageGrid(
        fig, 111,
        nrows_ncols=(2, tiles_per_row),
        axes_pad=0.1,
    )

    # BANDS
    bands = [6,] #CHANNELS_CONFIGURATIONS["all"]
    
    dl_iterator = enumerate(iloader)
    for _i in range(tiles_per_row):
        _, tile_data = next(dl_iterator)
        batch_index = 2
        rgb = np.clip(tile_data["image"][batch_index,(3,2,1),...].numpy().transpose(1,2,0)/3000.,0,1)
        labels = tile_data["mask"][batch_index,0]
                
        grid[_i].imshow(rgb)
        grid[tiles_per_row+ _i].imshow(labels,vmin=0,vmax=3)
        
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-28-9bd729e2aab2> in <module>
#      22     dl_iterator = enumerate(iloader)
#      23     for _i in range(tiles_per_row):
# ---> 24         _, tile_data = next(dl_iterator)
#      25         batch_index = 2
#      26         rgb = np.clip(tile_data["image"][batch_index,(3,2,1),...].numpy().transpose(1,2,0)/3000.,0,1)
#
# /opt/miniconda3/envs/floodbusters/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/miniconda3/envs/floodbusters/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     472
#     473     def _next_data(self):
# --> 474         index = self._next_index()  # may raise StopIteration
#     475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#
# /opt/miniconda3/envs/floodbusters/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_index(self)
#     425
#     426     def _next_index(self):
# --> 427         return next(self._sampler_iter)  # may raise StopIteration
#     428
#     429     def _next_data(self):
#
# StopIteration:

# %%
grid

# %%
tile_data.keys()
# Out:
# dict_keys(['image', 'mask'])
