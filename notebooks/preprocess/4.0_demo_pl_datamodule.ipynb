# %% [markdown]
# # PyTorch-Lightning Data Module
#
# In this module, we quickly demonstrate how to use the PyTorch-Lightning Module which already has the preliminary steps for preprocessing. We assume the data is already downloaded and organized in this demo.

# %%
# Helpful trick for loading the directories correction
import sys, os
from pyprojroot import here
# spyder up to find the root
root = here(project_files=[".here"])
# append to path
sys.path.append(str(here()))


from src.data.worldfloods.dataset import WorldFloodsDatasetTiled

# MATPLOTLIB Settings
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# SEABORN SETTINGS
import seaborn as sns
sns.set_context(context='talk',font_scale=0.7)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Demo Images
#
# For this demonstration, we need a S2 AND a groundtruth image. We have two that we can download.

# %%
from src.data.worldfloods.test_download import download_demo_trainsplit_image
from pathlib import Path

destination_dir = Path(root).joinpath("datasets/demo_images")

# %%
download_demo_trainsplit_image(dest_dir=destination_dir)
# Out:
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/train/S2' Is Already There.
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/train/gt' Is Already There.
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/val/S2' Is Already There.
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/val/gt' Is Already There.
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/test/S2' Is Already There.
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_images/test/gt' Is Already There.

# %%
# !ls $destination_dir
# Out:
# test  train  val

# %% [markdown]
# ## PL - DataModule

# %% [markdown]
# #### 1.1 - Initialize Data Module

# %%
wf_dm = WorldFloodsDataModule(
    data_dir=str(destination_dir),
)

# %% [markdown]
# #### 1.2 - Prepare Data

# %%
wf_dm.prepare_data()

# %% [markdown]
# #### 1.3 - Run Setup

# %%
wf_dm.setup()
# Out:
# /home/jemanjohnson34/projects/ml4floods/datasets/demo_images/train/S2
# /home/jemanjohnson34/projects/ml4floods/datasets/demo_images/test/S2
# /home/jemanjohnson34/projects/ml4floods/datasets/demo_images/val/S2

# %% [markdown]
# #### 1.4 - Load Datasets (Optional)

# %%
train_ds = wf_dm.train_dataset
val_ds = wf_dm.val_dataset
test_ds = wf_dm.test_dataset

print(len(wf_dm.train_dataset), len(wf_dm.val_dataset), len(wf_dm.test_dataset))
# Out:
# 1395 256 112

# %% [markdown]
# #### 1.5 - Load DataLoaders

# %%
train_dl = wf_dm.train_dataloader()
val_dl = wf_dm.val_dataloader()
test_dl = wf_dm.test_dataloader()

print(len(train_dl), len(val_dl), len(test_dl))
# Out:
# 44 8 4

# %% [markdown]
# ## Demo - Train/Val/Test

# %%
from rasterio.plot import show as rasterio_show
from mpl_toolkits.axes_grid1 import ImageGrid

for iloader in [train_ds, val_ds, test_ds]:

    n_tiles = 16
    n_rows = 2
    tiles_per_row = int(n_tiles / n_rows)
    iteration = 0

    # plot preamble
    fig = plt.figure(figsize=(40, 20))
    grid = ImageGrid(
        fig, 111,
        nrows_ncols=(1, tiles_per_row),
        axes_pad=0.1,
    )




    # BANDS
    bands = [6,] #CHANNELS_CONFIGURATIONS["all"]

    for iax, itile in zip(grid, range(n_tiles)):

        tile_data = iloader[itile]
    #     print(tile_data["image"].shape, tile_data["mask"].shape)
    #     print()
    #     if itile < 8:
        iax.imshow(tile_data["image"][6,:,:].squeeze())
    #         rasterio_show(tile_data["image"][6,:,:], ax=iax, cmap="pink")
    #     else:
    # #         rasterio_show(tile_data["mask"], ax=iax, cmap="pink")
    #         iax.imshow(tile_data["mask"][0,:,:].squeeze())
    plt.show()

    n_tiles = 16
    n_rows = 2
    tiles_per_row = int(n_tiles / n_rows)
    iteration = 0

    # plot preamble
    fig = plt.figure(figsize=(40, 20))
    grid = ImageGrid(
        fig, 111,
        nrows_ncols=(1, tiles_per_row),
        axes_pad=0.1,
    )




    # BANDS
    bands = [6,] #CHANNELS_CONFIGURATIONS["all"]

    for iax, itile in zip(grid, range(n_tiles)):

        tile_data = iloader[itile]
    #     print(tile_data["image"].shape, tile_data["mask"].shape)
        iax.imshow(tile_data["mask"][0,:,:].squeeze())
    #  
    plt.show()

# %% [markdown]
# ## Demo GC Bucket Directly

# %%
# class WorldFloodsGCPDataModule(pl.LightningDataModule):
#     def __init__(
#         self,
        
#         transformations: Optional[List[Callable]] = None,
#         window_size: Tuple[int,int]=[64,64],
#         batch_size: int = 32,
#         bands: List[int]=[1,2,3]
#     ):
#         super().__init__()
#         self.transform = albumentations.Compose(transformations) if transformations is not None else None
        
#         # WORLDFLOODS Directories
#         self.bucket_name = "ml4floods"
#         self.train_dir = "worldfloods/public/train/S2/"
#         self.val_dir = "worldfloods/public/val/S2/"
#         self.test_dir = "worldfloods/public/test/S2/"
        

#         # self.dims is returned when you call dm.size()
#         # Setting default dims here because we know them.
#         # Could optionally be assigned dynamically in dm.setup()
#         self.bands = bands
#         self.batch_size = batch_size
#         # Prefixes
#         self.image_prefix = "S2"
#         self.gt_prefix = "gt"
#         self.window_size = window_size

#     def prepare_data(self):
#         # TODO: potentially download the data
#         # TODO: create the train/test/val structure
#         # TODO: here we can check for correspondence between the files
#         pass

        
#     def setup(self):
            
#         # get filenames from the bucket
#         self.train_files = get_files_in_bucket_directory(self.bucket_name, self.train_dir, ".tif")
#         self.val_files = get_files_in_bucket_directory(self.bucket_name, self.val_dir, ".tif")
#         self.test_files = get_files_in_bucket_directory(self.bucket_name, self.test_dir, ".tif")
        
#         # add gcp dir to each of the strings
#         # TODO: make this cleaner...this feels hacky.
#         self.train_files = [f"gs://{self.bucket_name}/{x}" for x in self.train_files]
#         self.val_files = [f"gs://{self.bucket_name}/{x}" for x in self.val_files]
#         self.test_files = [f"gs://{self.bucket_name}/{x}" for x in self.test_files]
        
#         # create datasets
#         self.train_dataset = WorldFloodsDatasetTiled(
#             image_files=self.train_files, image_prefix=self.image_prefix,
#             gt_prefix=self.gt_prefix, window_size=self.window_size,
#             transforms=self.transform
#         )
#         self.val_dataset = WorldFloodsDatasetTiled(
#             image_files=self.val_files, image_prefix=self.image_prefix,
#             gt_prefix=self.gt_prefix, window_size=self.window_size,
#             transforms=self.transform
#         )
#         self.test_dataset = WorldFloodsDatasetTiled(
#             image_files=self.test_files, image_prefix=self.image_prefix,
#             gt_prefix=self.gt_prefix, window_size=self.window_size,
#             transforms=self.transform
#         )
        

#     def train_dataloader(self):
#         return DataLoader(self.train_dataset, batch_size=self.batch_size)

#     def val_dataloader(self):
#         return DataLoader(self.val_dataset, batch_size=self.batch_size)

#     def test_dataloader(self):
#         return DataLoader(self.test_dataset, batch_size=self.batch_size)

# %%
WorldFloodsGCPDataModule()

# %%
# get_files_in_bucket_directory("ml4floods", "worldfloods/public/train/S2", ".tif")

# %%
wf_dm = WorldFloodsGCPDataModule()
wf_dm.prepare_data()

wf_dm.setup()

train_ds = wf_dm.train_dataset
val_ds = wf_dm.val_dataset
test_ds = wf_dm.test_dataset

# train_dl = wf_dm.train_dataloader()
# val_dl = wf_dm.val_dataloader()
# test_dl = wf_dm.test_dataloader()

# %%
bucket_name = "gs://ml4floods/worldfloods/public"


wf_dm = WorldFloodsDataModule(
    data_dir=str(bucket_name),
)
wf_dm.prepare_data()

wf_dm.setup()

train_ds = wf_dm.train_dataset
val_ds = wf_dm.val_dataset
test_ds = wf_dm.test_dataset
# Out:
# gs:/ml4floods/worldfloods/public/train/S2
# gs:/ml4floods/worldfloods/public/test/S2
# gs:/ml4floods/worldfloods/public/val/S2

# %%
len(train_ds), len(test_ds), len(val_ds)
# Out:
# (3072159, 34903, 19371)

# %%
from rasterio.plot import show as rasterio_show
from mpl_toolkits.axes_grid1 import ImageGrid

train_ds = wf_dm.train_dataset
val_ds = wf_dm.val_dataset
test_ds = wf_dm.test_dataset

for iloader in [train_ds, val_ds, test_ds]:

    n_tiles = 16
    n_rows = 2
    tiles_per_row = int(n_tiles / n_rows)
    iteration = 0

    # plot preamble
    fig = plt.figure(figsize=(40, 20))
    grid = ImageGrid(
        fig, 111,
        nrows_ncols=(1, tiles_per_row),
        axes_pad=0.1,
    )




    # BANDS
    bands = [6,] #CHANNELS_CONFIGURATIONS["all"]

    for iax, itile in zip(grid, range(n_tiles)):

        tile_data = iloader[itile]
    #     print(tile_data["image"].shape, tile_data["mask"].shape)
    #     print()
    #     if itile < 8:
        iax.imshow(tile_data["image"][6,:,:].squeeze())
    #         rasterio_show(tile_data["image"][6,:,:], ax=iax, cmap="pink")
    #     else:
    # #         rasterio_show(tile_data["mask"], ax=iax, cmap="pink")
    #         iax.imshow(tile_data["mask"][0,:,:].squeeze())
    plt.show()

    n_tiles = 16
    n_rows = 2
    tiles_per_row = int(n_tiles / n_rows)
    iteration = 0

    # plot preamble
    fig = plt.figure(figsize=(40, 20))
    grid = ImageGrid(
        fig, 111,
        nrows_ncols=(1, tiles_per_row),
        axes_pad=0.1,
    )




    # BANDS
    bands = [6,] #CHANNELS_CONFIGURATIONS["all"]

    for iax, itile in zip(grid, range(n_tiles)):

        tile_data = iloader[itile]
    #     print(tile_data["image"].shape, tile_data["mask"].shape)
        iax.imshow(tile_data["mask"][0,:,:].squeeze())
    #  
    plt.show()
