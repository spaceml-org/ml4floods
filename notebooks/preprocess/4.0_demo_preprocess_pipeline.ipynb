# %% [markdown]
# ## Notebook to create a worldfloods dataloader

# %%
import sys, os
from pathlib import Path
from pyprojroot import here
# spyder up to find the root
root = here(project_files=[".here"])
# append to path
sys.path.append(str(here()))

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Step 1: Setup Configuration file

# %%
from src.models.utils.configuration import AttrDict
from src.data.worldfloods.configs import CHANNELS_CONFIGURATIONS

opt = {
    "data_params": {
        "bucket_id": "ml4floods",
        "path_to_splits": "worldfloods/public",
        "input_folder": "S2",
        "target_folder": "gt",
        "batch_size": 8,
        "window_size": [256, 256],
        "bands": "all",
        "train_transformation": {
            "num_classes": 3,
            "resizefactor": {
                "downsampling_factor": 3,
                "p": 1.0
            },
            "normalize": True,
            "shiftscalerotate": {
                "shift_limit": 0.001,
                "scale_limit": 0.01,
                "rotate_limit": 0.01,
                "p": 0.5
            },
            "gaussnoise": {
                "var_limit_lower": 1e-6,
                "var_limit_upper": 1e-3,
                "p": 0.2
            },
            "motionblur": {
                "blur_limit": 7,
                "always_apply": False
            },
            "totensor": True,
            "use_channels": "all"
        },
        "test_transformation": {
            "num_classes": 3,
            "resizefactor": None,
            "shiftscalerotate": None,
            "gaussnoise": None,
            "motionblur": None,
            "totensor": True,
            "use_channels": "all",
            "normalize": True
        }
    }
}
opt = AttrDict.from_nested_dicts(opt)

# %% [markdown]
# ### Step 2: Setup Transformations

# %%
# ### Option 1: generate from config
# from src.preprocess.transformations import transforms_generator

# train_transform = transforms_generator(opt.data_params.train_transformation)
# test_transform = transforms_generator(opt.data_params.test_transformation)

### Option 2: create manually
import src.preprocess.transformations as transformations

# %% [markdown]
# #### Normalization
#
# This is a special step.

# %%
from src.preprocess.worldfloods import normalize as wf_normalization


channel_mean, channel_std = wf_normalization.get_normalisation(opt.data_params.train_transformation.use_channels)

# %% [markdown]
# #### Training Transformations

# %%
train_transform = transformations.Compose([
    transformations.InversePermuteChannels(), 
#     transformations.GaussNoise(var_limit=(1e-6, 1e-3), mean=0.0, p=0.0),
#     transformations.MotionBlur(blur_limit=100, always_apply=True, p=1.0),
    transformations.RandomRotate90(always_apply=True, p=1.0),
    transformations.Flip(always_apply=True, p=1.0),
    transformations.Normalize(
        mean=channel_mean, 
        std=channel_std, 
        max_pixel_value=1),
    transformations.PermuteChannels(), 
    transformations.ToTensor(),
])

# %% [markdown]
# #### Test Transformations

# %%
test_transform = transformations.Compose([ 
    transformations.InversePermuteChannels(), 
    transformations.Normalize(
        mean=channel_mean, 
        std=channel_std, 
        max_pixel_value=1),
    transformations.PermuteChannels(),
    transformations.ToTensor(),
])

# %% [markdown]
# ### Step 3a: Setup Dataloaders (A)
#     - loader reads from bucket
#     - loader handles tiling for us

# %%
from src.data.worldfloods.lightning import WorldFloodsGCPDataModule
from src.preprocess.tiling import WindowSize

# parameters
bands = CHANNELS_CONFIGURATIONS[opt.data_params.bands]
window_size = WindowSize(height=opt.data_params.window_size[0], width=opt.data_params.window_size[1])

# initialize the GCP Data Module
wf_gcp_dm = WorldFloodsGCPDataModule(
    bucket_id=opt.data_params.bucket_id,
    path_to_splits=opt.data_params.path_to_splits,
    input_folder=opt.data_params.input_folder,
    target_folder=opt.data_params.target_folder,
    window_size=window_size,
    bands=bands,
    train_transformations=train_transform,
    test_transformations=test_transform,
)

# %% [markdown]
# #### Prepare + Setup
#
# Already predefined methods to do all of the plumbing.

# %%
# pytorch-lightning convention
wf_gcp_dm.prepare_data()
wf_gcp_dm.setup()

# %%
# check the number of datapoints available
print(wf_gcp_dm.train_dataset.__len__())
# Out:
# 196648

# %% [markdown]
# ### Plot some examples from dataloaders
#
# This is a quick demo to show a few of the images.

# %%
import matplotlib.pyplot as plt
import numpy as np
from rasterio.plot import show as rasterio_show

train_dl = wf_gcp_dm.train_dataloader()
test_dl = wf_gcp_dm.test_dataloader()

for i, sample in enumerate(train_dl):
    
    if i < 5:
        fig, ax = plt.subplots(1,2)
        image = sample['image'][0][[6], :, :].numpy().transpose(2,0,1)
        mask = sample['mask'][0][[0], :, :].numpy().transpose(2,0,1).squeeze()
        rasterio_show(image, ax=ax[0])
        ax[1].imshow(mask)
        plt.show()
    else:
        break

# %% [markdown]
# ### Step 3b: Setup Dataloaders (B)
#     - load data from bucket to machine (load images)
#     - loader handles tiling for us

# %%
from src.preprocess.tiling import save_tiles, WindowSize
from src.data.worldfloods.configs import CHANNELS_CONFIGURATIONS
from src.data.utils import get_files_in_bucket_directory, save_file_from_bucket

# %%
num_examples = 1

bands = CHANNELS_CONFIGURATIONS[opt.data_params.bands]
window_size = WindowSize(height=opt.data_params.window_size[0], width=opt.data_params.window_size[1])

destination_dir = Path(root).joinpath(f"datasets/demo/")

filenames = {
    "train": {},
    "val": {},
    "test": {}
}

for split in filenames.keys():
    filenames[split][opt.data_params.input_folder] = get_files_in_bucket_directory(opt.data_params.bucket_id, f"{opt.data_params.path_to_splits}/{split}/{opt.data_params.input_folder}", suffix=".tif")[:num_examples]
    filenames[split][opt.data_params.target_folder] = get_files_in_bucket_directory(opt.data_params.bucket_id, f"{opt.data_params.path_to_splits}/{split}/{opt.data_params.target_folder}", suffix=".tif")[:num_examples]
    
print(filenames)
# Out:
# {'train': {'S2': ['worldfloods/public/train/S2/01042016_Choctawhatchee_River_near_Bellwood_AL.tif'], 'gt': ['worldfloods/public/train/gt/01042016_Choctawhatchee_River_near_Bellwood_AL.tif']}, 'val': {'S2': ['worldfloods/public/val/S2/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif'], 'gt': ['worldfloods/public/val/gt/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif']}, 'test': {'S2': ['worldfloods/public/test/S2/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif'], 'gt': ['worldfloods/public/test/gt/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif']}}

# %% [markdown]
# ### Download images from bucket

# %%
from src.data.utils import create_folder

for split in filenames.keys():
    for k in filenames[split].keys():
        # create the destination folder
        create_folder(f"{destination_dir}/{split}/{k}")
        print(f'Loading files to {destination_dir}/{split}/{k}')
        
        # loop through the tiling
        for fp in filenames[split][k]:
            save_file_from_bucket(opt.data_params.bucket_id, fp, f"{destination_dir}/{split}/{k}/")
            print(f"Loaded {fp}")
# Out:
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/train/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/train/S2
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/train/S2/' Is Already There.
# Loaded worldfloods/public/train/S2/01042016_Choctawhatchee_River_near_Bellwood_AL.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/train/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/train/gt
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/train/gt/' Is Already There.
# Loaded worldfloods/public/train/gt/01042016_Choctawhatchee_River_near_Bellwood_AL.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/val/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/val/S2
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/val/S2/' Is Already There.
# Loaded worldfloods/public/val/S2/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/val/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/val/gt
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/val/gt/' Is Already There.
# Loaded worldfloods/public/val/gt/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/test/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/test/S2
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/test/S2/' Is Already There.
# Loaded worldfloods/public/test/S2/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/test/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo/test/gt
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo/test/gt/' Is Already There.
# Loaded worldfloods/public/test/gt/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif

# %% [markdown]
# ### Setup Dataloader

# %%
from src.data.worldfloods.lightning import WorldFloodsDataModule

# %%
# initialize dataloader
wf_local_dm = WorldFloodsDataModule(
    input_folder=opt.data_params.input_folder,
    target_folder=opt.data_params.target_folder,
    train_transformations=train_transform,
    test_transformations=test_transform,
    data_dir=str(destination_dir)
)

# %% [markdown]
# #### Prepare + Setup

# %%
# pytorch-lightning convention
wf_local_dm.prepare_data()
wf_local_dm.setup()

# %%
# check the number of datapoints available
print(wf_local_dm.train_dataset.__len__())
# Out:
# 21646

# %%
import matplotlib.pyplot as plt
import numpy as np
from rasterio.plot import show as rasterio_show

test_dl = wf_local_dm.test_dataloader()

for i, sample in enumerate(test_dl):
        
    if i < 5:
        fig, ax = plt.subplots(1,2)
        image = sample['image'][0][[6], :, :].numpy().transpose(2,0,1)
        mask = sample['mask'][0][[0], :, :].numpy().transpose(2,0,1).squeeze()
        rasterio_show(image, ax=ax[0])
        ax[1].imshow(mask)
        plt.show()
    else:
        break

# %% [markdown]
# ### Step 3c: Setup Dataloaders (C)
#     - load data from bucket to machine (load tiles)
#     - pass tiled images to dataloader
#
# **WARNINGS**: This cell takes a long time to run!

# %%
# %%time

for split in filenames.keys():
    for k in filenames[split].keys():
        # create the folder
        create_folder(f"{destination_dir}_tiles/{split}/{k}")
        print(f'Loading files to {destination_dir}_tiles/{split}/{k}')
        
        # select specific bands
        cur_bands = bands if opt.data_params.input_folder == k else [1,]
        
        # save files
        for fp in filenames[split][k]:            
            save_tiles(f"gs://{opt.data_params.bucket_id}/{fp}", f"{destination_dir}_tiles/{split}/{k}/", cur_bands, window_size)
            print(f'Loaded {fp}')
# Out:
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/train/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/train/S2
# Loaded worldfloods/public/train/S2/01042016_Choctawhatchee_River_near_Bellwood_AL.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/train/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/train/gt
# Loaded worldfloods/public/train/gt/01042016_Choctawhatchee_River_near_Bellwood_AL.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/val/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/val/S2
# Loaded worldfloods/public/val/S2/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/val/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/val/gt
# Loaded worldfloods/public/val/gt/EMSR271_02FARKADONA_DEL_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/test/S2' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/test/S2
# Loaded worldfloods/public/test/S2/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif
# Folder '/home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/test/gt' is created.
# Loading files to /home/jemanjohnson34/projects/ml4floods/datasets/demo_tiles/test/gt
# Loaded worldfloods/public/test/gt/EMSR286_08ITUANGONORTH_DEL_MONIT02_v1_observed_event_a.tif

# %%
destination_dir
# Out:
# PosixPath('/home/jemanjohnson34/projects/ml4floods/datasets/demo')

# %%
from src.data.worldfloods.lightning import WorldFloodsDataModule

destination_dir = Path(root).joinpath(f"datasets/demo/")

# initialize dataloader
wf_local_tiles_dm = WorldFloodsDataModule(
    input_folder=opt.data_params.input_folder,
    target_folder=opt.data_params.target_folder,
    train_transformations=train_transform,
    test_transformations=test_transform,
    data_dir=f"{destination_dir}_tiles/"
)

# %% [markdown]
# #### Prepare + Setup

# %%
# %%time

# pytorch-lightning convention
wf_local_tiles_dm.prepare_data()
wf_local_tiles_dm.setup()
# Out:
# CPU times: user 1min 50s, sys: 2.48 s, total: 1min 53s
# Wall time: 1min 53s

# %%
# check the number of datapoints available
print(wf_local_tiles_dm.train_dataset.__len__())
# Out:
# 22400

# %%
import matplotlib.pyplot as plt
import numpy as np
from rasterio.plot import show as rasterio_show

test_dl = wf_local_tiles_dm.test_dataloader()

for i, sample in enumerate(test_dl):
    if i < 5:
        fig, ax = plt.subplots(1,2)
        image = sample['image'][0][[6], :, :].numpy().transpose(2,0,1)
        mask = sample['mask'][0][[0], :, :].numpy().transpose(2,0,1).squeeze()
        rasterio_show(image, ax=ax[0])
        ax[1].imshow(mask)
        plt.show()
    else:
        break
